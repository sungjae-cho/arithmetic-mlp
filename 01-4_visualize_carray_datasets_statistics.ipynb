# %%
from data_utils import plot_carry_dataset_statistics
# %matplotlib inline
plot_carry_dataset_statistics(mode='show')
plot_carry_dataset_statistics(mode='save', file_format='pdf')
# Out:
# plot_figures/carry_dataset_statistics_4-digit_operand.pdf saved!
# plot_figures/carry_dataset_statistics_6-digit_operand.pdf saved!
# plot_figures/carry_dataset_statistics_8-digit_operand.pdf saved!
