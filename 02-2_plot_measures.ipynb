# %%
import matplotlib.pyplot as plt
import utils

# %%
experiment_name = 'cogsci2019'
run_id = '20181128141708'
measure_logs = utils.read_measure_logs(experiment_name, run_id)

# %%
measure_logs.keys()
# Out:
# dict_keys(['digit-1_op_wrong', 'digit-3_accuracy', 'digit-5_accuracy', 'digit-4_op_wrong', 'tlu_test_accuracy', 'digit-2_accuracy', 'float_epoch', 'digit-5_op_wrong', 'digit-1_accuracy', 'tlu_test_loss', 'test_accuracy', 'test_loss', 'test_op_wrong', 'tlu_op_wrong', 'digit-3_op_wrong', 'digit-4_accuracy', 'digit-2_op_wrong'])

# %%
x_name = 'float_epoch'
y_name = 'test_loss'
x = measure_logs[x_name]
y = measure_logs[y_name]

# %%
plt.title('Wrong answers by epochs to the conquest epoch:\nAdd multilayer percetron')
plt.xlabel('Epochs')
plt.ylabel('Wrong answers')
plt.plot(x, y)
plt.savefig('wrong_by_epochs.pdf')
plt.savefig('wrong_by_epochs.png')
